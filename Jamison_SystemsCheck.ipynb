# %% [markdown]
# # Systems Check Assignment

# %% [markdown]
# ## What I hope to get out of this class

# %% [markdown]
# 1. To learn how to *access*, *comb*, and *clean* datasets.
# 2. To display the data in different styles of *graphs* for the **audience** to view.
# 3. To gain a basic understanding of how to code with **Python**.

# %% [markdown]
# ![Smiski with a laptop](Laptopsmiski.jpg)

# %%
smiskiSeries = ["Yoga", "Construction", "Bed"]
for x in smiskiSeries:
    print(x)
# Out:
# Yoga
# Construction
# Bed

# %%
def multiplyNumbers(a, b):
    result = a*b
    return result
multiplyNumbers(5, 8)
# Out:
# 40
